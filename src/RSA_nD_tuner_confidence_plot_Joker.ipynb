# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# =========================
# 1️⃣ Configuration
# =========================
observable = 'Joker'
observable = 'Joker_locked'
run_nm     = '8'
run_nm     = '3'

plot_configs = {
    'Joker': {
        '3': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '4': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '5': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '6': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '7': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '8': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '1': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '2': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
    },
    'Joker_locked': {
        '1': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/2D/',
            'xlabel': r'$a_x$',
            'ylabel': r'$b_x$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
        '2': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/',
            'xlabel': r'$a_x$',
            'ylabel': r'$b_x$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.04, 0.88),
            'target_point': (0.68, 0.98),
        },
        '3': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/',
            'xlabel': r'$a_x$',
            'ylabel': r'$b_x$',
            'title':  'RSA Tuning Trajectories — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   50,
            # Base & target points
            'base_point':   (0.68 + 0.04, 0.88),
            'target_point': (0.68, 0.98),
        },
    },
}

def get_config(obs, run):
    try:
        return plot_configs[obs][run]
    except KeyError:
        raise ValueError(f"No config found for observable='{obs}', run='{run}'")

config = get_config(observable, run_nm)
data_folder = config['data_folder']

# =========================
# 2️⃣ Load data
# =========================
points = np.load(os.path.join(data_folder, f'all_params_{run_nm}.npy'))
print(points.shape)
loss_values = np.load(os.path.join(data_folder, f'loss_values_{run_nm}.npy'))

print("Loaded points:", points.shape)
print("Loaded losses:", loss_values.shape)

# Handle both single and multi-trajectory formats
if points.ndim == 2:
    points = points[None, :, :]
n_traj, n_steps, _ = points.shape

# =========================
# 3️⃣ Setup figure
# =========================
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

# ---- Left: parameter trajectories ----
ax = axs[0]
colors = plt.cm.plasma(np.linspace(0, 1, n_traj))
for i in range(n_traj):
    x, y = points[i, :, 0], points[i, :, 1]
    ax.plot(x, y, '-', color=colors[i], linewidth=1.1, alpha=0.8, zorder=1)
    # ax.scatter(x, y, s=config['size'] * 0.6, color=colors[i], marker=config['marker'],
    #            edgecolors='k', linewidths=0.3, zorder=2)

    # Final fitted point (lime diamond)
    ax.scatter(x[-1], y[-1], c='lime', edgecolors='black', s=100, marker='D',
               label='Final fit' if i == 0 else "", zorder=3)

# Base and target points
if 'base_point' in config:
    bx, by = config['base_point']
    ax.scatter(bx, by, c='blue', marker='s', s=120, edgecolors='k', label='Base', zorder=4)
if 'target_point' in config:
    tx, ty = config['target_point']
    ax.scatter(tx, ty, c='magenta', marker='P', s=130, edgecolors='k', label='Target', zorder=5)

# Minimum-loss point
min_idx = np.unravel_index(np.argmin(loss_values), loss_values.shape)
print(min_idx)
# min_point = points[min_idx[0], min_idx[1]]
# ax.scatter(min_point[0], min_point[1], c='yellow', s=140, marker='*',
#            edgecolors='k', label='Min loss', zorder=6)

# ---- Axes formatting ----
ax.set_title(config['title'], fontsize=12, weight='bold')
ax.set_xlabel(config['xlabel'], fontsize=11)
ax.set_ylabel(config['ylabel'], fontsize=11)
ax.legend(frameon=True, loc='best', fontsize=9)
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_aspect('equal', adjustable='box')

# ---- Right: loss evolution ----
ax2 = axs[1]
if loss_values.ndim == 1:
    steps = np.arange(1, len(loss_values) + 1)
    ax2.plot(steps, loss_values, '-', color='tab:blue', markersize=4, linewidth=1.3, label='Loss')
    ax2.scatter(steps[-1], loss_values[-1], c='red', s=70, zorder=3, label='Final loss')
else:
    steps = np.arange(1, loss_values.shape[1] + 1)
    for i in range(loss_values.shape[0]):
        ax2.plot(steps, loss_values[i], '-', color=colors[i], alpha=0.7)
    mean_loss = np.mean(loss_values, axis=0)
    ax2.plot(steps, mean_loss, '-', color='black', markersize=4, linewidth=1.5, label='Mean loss')
    ax2.scatter(np.argmin(mean_loss)+1, np.min(mean_loss), c='yellow', s=80, marker='*',
                edgecolors='k', label='Min loss', zorder=5)

ax2.set_xlabel('Tuning step', fontsize=11)
ax2.set_ylabel('Loss value', fontsize=11)
ax2.set_title('Loss evolution', fontsize=12, weight='bold')
ax2.legend(frameon=True, loc='best', fontsize=9)
ax2.grid(True, linestyle='--', alpha=0.6)

# =========================
# 4️⃣ Save and show
# =========================
plt.tight_layout()
out_dir = os.path.join(data_folder, 'plots')
os.makedirs(out_dir, exist_ok=True)
out_path = os.path.join(out_dir, f'{observable}_tuning_map_{run_nm}.png')
plt.savefig(out_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Plot saved to: {out_path}")
# Out:
# (100, 76, 6)
# Loaded points: (100, 76, 6)
# Loaded losses: (100, 75)
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# (np.int64(58), np.int64(74))
# ✅ Plot saved to: /pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/plots/Joker_locked_tuning_map_3.png

# %%
points = np.load('/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/2D/all_params_1.npy')
print(points.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 points = np.load('/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/2D/all_params_1.npy')
#       2 print(points.shape)
#
# File /pscratch/sd/l/ljpuslar/.conda/envs/pt311_new/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/2D/all_params_1.npy'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2
from matplotlib.patches import Ellipse

# =========================
# 1️⃣ Configuration
# =========================
observable = 'Joker'
observable = 'Joker_locked'
run_nm     = '7'
run_nm     = '3'

plot_configs = {
    'Joker': {
        '7': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/2D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   25,
            # Base & target points
            'base_point':   (0.68 + 0.1275, 0.905),
            'target_point': (0.68, 0.98),
        },
    },
    'Joker_locked': {
        '2': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   25,
            # Base & target points
            'base_point':   (0.68 + 0.04, 0.88),
            'target_point': (0.68, 0.98),
        },
    },
    'Joker_locked': {
        '3': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'title':  'RSA Tuning — Joker (2D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   25,
            # Base & target points
            'base_point':   (0.68 + 0.04, 0.88),
            'target_point': (0.68, 0.98),
        },
    },
}

def get_config(obs, run):
    try:
        return plot_configs[obs][run]
    except KeyError:
        raise ValueError(f"No config found for observable='{obs}', run='{run}'")

config = get_config(observable, run_nm)
data_folder = config['data_folder']

# =========================
# 2️⃣ Load data
# =========================
points = np.load(os.path.join(data_folder, f'all_params_{run_nm}.npy'))
loss_values = np.load(os.path.join(data_folder, f'loss_values_{run_nm}.npy'))

if points.ndim == 2:
    points = points[None, :, :]
n_traj, n_steps, _ = points.shape

print(f"Loaded points: {points.shape}")
print(f"Loaded losses: {loss_values.shape}")

# =========================
# 3️⃣ Plot setup
# =========================
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(6, 6))

# Color gradient across all points
colors = plt.cm.plasma(np.linspace(0.1, 0.9, n_traj))

# ---- Scatter trajectories ----
xs, ys = [], []
for i in range(n_traj):
    x, y = points[i, -1, 0], points[i, -1, 1]
    # print(len(x))
    # Alpha fades slightly with step
    # alphas = np.linspace(0.3, 0.9, len(x))
    # ax.scatter(
    #     x, y,
    #     s=config['size'],
    #     c='blue',
    #     alpha=0.5,
    #     edgecolors='none',
    #     marker=config['marker'],
    #     zorder=1
    # )
    xs.append(x)
    ys.append(y)

# Confidence ellipse:
data = np.vstack((xs, ys))
print("Data shape for ellipse:", data.shape)

# Covariance and mean
cov = np.cov(data)
mean = np.mean(data, axis=1)

# Eigenvalues and eigenvectors
vals, vecs = np.linalg.eigh(cov)

# Sort by largest eigenvalue
order = vals.argsort()[::-1]
vals, vecs = vals[order], vecs[:, order]

# 95% confidence level
chi2_val = chi2.ppf(0.95, df=2)
width, height = 2 * np.sqrt(vals * chi2_val)  # full lengths
angle = np.degrees(np.arctan2(*vecs[:,0][::-1]))

# Plot
# fig, ax = plt.subplots()
ax.scatter(xs, ys, s=10, alpha=0.5, label='Parameter fits')
ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle,
                  edgecolor='red', facecolor='none',linestyle='--', lw=2, label='95% confidence ellipse')
ax.add_patch(ellipse)

ax.set_aspect('equal')

# ---- Key points ----
bx, by = config.get('base_point', (None, None))
tx, ty = config.get('target_point', (None, None))
if bx is not None:
    ax.scatter(bx, by, c='blue', marker='s', s=90, edgecolors='k', linewidths=0.5, label='Base', zorder=3)
if tx is not None:
    ax.scatter(tx, ty, c='magenta', marker='P', s=100, edgecolors='k', linewidths=0.5, label='Target', zorder=4)

# ---- Min-loss point ----
min_idx = np.unravel_index(np.argmin(loss_values), loss_values.shape)
min_point = points[min_idx[0], min_idx[1]]
ax.scatter(min_point[0], min_point[1], c='yellow', s=120, marker='*',
           edgecolors='k', linewidths=0.6, label='Min loss', zorder=5)

# ---- Formatting ----
ax.set_title(config['title'], fontsize=13, weight='bold')
ax.set_xlabel(config['xlabel'], fontsize=12)
ax.set_ylabel(config['ylabel'], fontsize=12)
ax.legend(frameon=True, loc='best', fontsize=9)
ax.set_aspect('equal', adjustable='box')

# Aesthetic tweaks
ax.tick_params(axis='both', which='major', labelsize=10)
ax.grid(True, linestyle='--', alpha=0.4)
for spine in ax.spines.values():
    spine.set_alpha(0.4)

plt.tight_layout()

# =========================
# 4️⃣ Save & show
# =========================
out_dir = os.path.join(data_folder, 'plots')
os.makedirs(out_dir, exist_ok=True)
out_path = os.path.join(out_dir, f'{observable}_scatter_{run_nm}.png')
plt.savefig(out_path, dpi=300, bbox_inches='tight', transparent=True)
plt.show()

print(f"✅ Scatter plot saved to: {out_path}")
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# Loaded points: (100, 76, 6)
# Loaded losses: (100, 75)
# Data shape for ellipse: (2, 100)
# ✅ Scatter plot saved to: /pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/locked/6D/plots/Joker_locked_scatter_3.png

# %%
import matplotlib
matplotlib.use("WebAgg")
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 (needed for 3D plots)

# =========================
# 1️⃣ Configuration
# =========================
observable = 'Joker'
run_nm     = '3'

plot_configs = {
    'Joker': {
        '1': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/3D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'zlabel': r'$\sigma$',
            'title':  'RSA Tuning Trajectories — Joker (3D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   40,
            # Base & target points (optional)
            'base_point':   (0.68 + 0.1275, 0.905, 0.2925),
            'target_point': (0.68, 0.98, 0.27125),
        },
        '2': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/3D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'zlabel': r'$\sigma$',
            'title':  'RSA Tuning Trajectories — Joker (3D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   40,
            # Base & target points (optional)
            'base_point':   (0.68 + 0.085, 0.93, 0.2925),
            'target_point': (0.68, 0.98, 0.27125),
            # 'base_point':   (0.68 + 0.1275, 0.905, 0.2925),
            # 'target_point': (0.68, 0.98, 0.27125),
        },
        '3': {
            'data_folder': '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/3D/',
            'xlabel': r'$a_d$',
            'ylabel': r'$b_d$',
            'zlabel': r'$\sigma$',
            'title':  'RSA Tuning Trajectories — Joker (3D)',
            'color':  'tab:red',
            'marker': 'o',
            'size':   40,
            # Base & target points (optional)
            'base_point':   (0.68 + 0.085, 0.93, 0.2925),
            'target_point': (0.68, 0.98, 0.27125),
            # 'base_point':   (0.68 + 0.1275, 0.905, 0.2925),
            # 'target_point': (0.68, 0.98, 0.27125),
        },
    },
}

def get_config(obs, run):
    try:
        return plot_configs[obs][run]
    except KeyError:
        raise ValueError(f"No config found for observable='{obs}', run='{run}'")

config = get_config(observable, run_nm)
data_folder = config['data_folder']

# =========================
# 2️⃣ Load data
# =========================
points = np.load(os.path.join(data_folder, f'all_params_{run_nm}.npy'))
loss_values = np.load(os.path.join(data_folder, f'loss_values_{run_nm}.npy'))

print("Loaded points:", points.shape)
print("Loaded losses:", loss_values.shape)

# Handle both single and multi-trajectory formats
if points.ndim == 2:
    points = points[None, :, :]
n_traj, n_steps, n_dim = points.shape
if n_dim != 3:
    raise ValueError(f"Expected 3D points, but got {n_dim}D data")

# =========================
# 3️⃣ Setup figure
# =========================
fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax2 = fig.add_subplot(1, 2, 2)

colors = plt.cm.plasma(np.linspace(0, 1, n_traj))

# ---- Left: 3D parameter trajectories ----
for i in range(n_traj):
    x, y, z = points[i, :, 0], points[i, :, 1], points[i, :, 2]
    # ax.plot(x, y, z, '', color=colors[i], linewidth=1.1, alpha=0.8, zorder=1)
    # ax.scatter(x, y, z, s=config['size'] * 0.7, color=colors[i], marker=config['marker'],
    #            edgecolors='k', linewidths=0.3, zorder=2)

    # Final fitted point
    ax.scatter(x[-1], y[-1], z[-1], c='lime', edgecolors='black', s=100, marker='D',
               label='Final fit' if i == 0 else "", zorder=3)

# Base and target points
if 'base_point' in config:
    bx, by, bz = config['base_point']
    ax.scatter(bx, by, bz, c='blue', marker='s', s=120, edgecolors='k', label='Base', zorder=4)
if 'target_point' in config:
    tx, ty, tz = config['target_point']
    ax.scatter(tx, ty, tz, c='magenta', marker='P', s=130, edgecolors='k', label='Target', zorder=5)

# Minimum-loss point
min_idx = np.unravel_index(np.argmin(loss_values), loss_values.shape)
min_point = points[min_idx[0], min_idx[1]]
ax.scatter(min_point[0], min_point[1], min_point[2], c='yellow', s=140, marker='*',
           edgecolors='k', label='Min loss', zorder=6)

# ---- Formatting ----
ax.set_title(config['title'], fontsize=12, weight='bold')
ax.set_xlabel(config['xlabel'], fontsize=11)
ax.set_ylabel(config['ylabel'], fontsize=11)
ax.set_zlabel(config['zlabel'], fontsize=11)
ax.legend(frameon=True, loc='best', fontsize=9)
ax.view_init(elev=90., azim=-15)
ax.grid(True, linestyle='--', alpha=0.5)

# ---- Right: loss evolution ----
if loss_values.ndim == 1:
    steps = np.arange(1, len(loss_values) + 1)
    ax2.plot(steps, loss_values, 'o', color='tab:blue', markersize=4, linewidth=1.3, label='Loss')
    ax2.scatter(steps[-1], loss_values[-1], c='red', s=70, zorder=3, label='Final loss')
else:
    steps = np.arange(1, loss_values.shape[1] + 1)
    for i in range(loss_values.shape[0]):
        ax2.plot(steps, loss_values[i], '-', color=colors[i], alpha=0.7)
    mean_loss = np.mean(loss_values, axis=0)
    ax2.plot(steps, mean_loss, '-o', color='black', markersize=4, linewidth=1.5, label='Mean loss')
    ax2.scatter(np.argmin(mean_loss)+1, np.min(mean_loss), c='yellow', s=80, marker='*',
                edgecolors='k', label='Min loss', zorder=5)

ax2.set_xlabel('Tuning step', fontsize=11)
ax2.set_ylabel('Loss value', fontsize=11)
ax2.set_title('Loss evolution', fontsize=12, weight='bold')
ax2.legend(frameon=True, loc='best', fontsize=9)
ax2.grid(True, linestyle='--', alpha=0.6)

# =========================
# 4️⃣ Save and show
# =========================
plt.tight_layout()
out_dir = os.path.join(data_folder, 'plots')
os.makedirs(out_dir, exist_ok=True)
out_path = os.path.join(out_dir, f'{observable}_tuning_map_{run_nm}_3D.png')
plt.savefig(out_path, dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ 3D plot saved to: {out_path}")
# Out:
# Loaded points: (100, 76, 3)
# Loaded losses: (100, 75)
# ✅ 3D plot saved to: /pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_Confidence_ND/Joker/3D/plots/Joker_tuning_map_3_3D.png

# %%
datafolder = '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_confidence/'
# points = np.load('/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner/jupyter/ADAgrad_N50k_3/RSA_tuning_params.npy')
all_points = np.load(datafolder + f'all_params_{save_nm}.npy')
print(np.shape(all_points))

# points = all_params
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for points in all_points:

    # Unpack the three columns
    # x, y, z = points[::10, 0], points[::10, 1], points[::10, 2]
    x, y, z = points[:, 0], points[:, 1], points[:, 2]
    # x, y, z = points[:10, 0], points[:10, 1], points[:10, 2]
    # x, y, z = points[-10:, 0], points[-10:, 1], points[-10:, 2]

    ax.plot(x, y, z, marker='o')  # 3D scatter plot
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Scatter Plot')
    ax.view_init(elev=15, azim=65)
    # print(x[0:5], y[0:5], z[0:5])
plt.plot(x[0], y[0], z[0], marker='o', color='red', markersize=10)  # Start point
plt.tight_layout()
ax.view_init(elev=0, azim=40)
plt.show()
# Out:
# (285, 101, 3)

# %%
import matplotlib.pyplot as plt
datafolder = '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_confidence/'
# points = np.load('/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner/jupyter/ADAgrad_N50k_3/RSA_tuning_params.npy')
all_loss = np.load(datafolder + f'loss_values_{save_nm}.npy')

plt.figure()
print(np.shape(all_loss))
for loss in all_loss:
    plt.plot(loss)
plt.xlabel('Iterations')
plt.ylabel('loss value')
plt.yscale('log')
# Out:
# (285, 100)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plotting
from matplotlib import cm
from matplotlib.colors import Normalize


datafolder = '/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner_confidence/'
# points = np.load('/pscratch/sd/l/ljpuslar/RSA/RSA/src/temp_results/Tuner/jupyter/ADAgrad_N50k_3/RSA_tuning_params.npy')
save_nm = 5
points = np.load(datafolder + f'params_final_{save_nm}.npy')
all_loss = np.load(datafolder + f'loss_values_{save_nm}.npy')
loss_values_final = all_loss[:, -1]

norm = Normalize(vmin=np.min(loss_values_final), vmax=np.max(loss_values_final))
cmap = cm.viridis
colors = cmap(norm(loss_values_final))

print(np.shape(points))

# points = all_params

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Unpack the three columns
x, y, z = points[:, 0], points[:, 1], points[:, 2]

xm, ym, zm = np.mean(x), np.mean(y), np.mean(z)

ax.scatter(x, y, z, marker='o', c=colors, alpha=1)

# Create ScalarMappable for colorbar
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Required for older versions of matplotlib

# Add colorbar
cbar = plt.colorbar(sm, ax=ax, label='Loss')

# put mean point in red big size over all other points making it stand out from others by being in front using the zorder
ax.scatter(xm, ym, zm, marker='o', c='red', s=100, zorder=0, label=f'Mean: ({xm:.3f},{ym:.3f},{zm:.3f})')  # Mean point
# ax.scatter(0.68, 0.98, 0.335, marker='o', c='black', s=100, zorder=0)  # Mean point
# ax.scatter(0.74, 0.88, 0.330, marker='o', c='red', s=100, zorder=0)  # Mean point
ax.set_xlabel('a_d')
ax.set_ylabel('b_d')
ax.set_zlabel('sigma')
ax.set_title('3D Scatter Plot')
ax.view_init(elev=0, azim=45)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# (285, 3)
